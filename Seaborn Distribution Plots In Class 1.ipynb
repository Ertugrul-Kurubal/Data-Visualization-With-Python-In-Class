# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
diamonds=sns.load_dataset('diamonds')
exercise=sns.load_dataset('exercise')
flights=sns.load_dataset('flights')
geyser=sns.load_dataset('geyser')
iris=sns.load_dataset('iris')
penguins=sns.load_dataset('penguins')
planets=sns.load_dataset('planets')
mpg=sns.load_dataset('mpg')
tips = sns.load_dataset('tips')
titanic=sns.load_dataset('titanic')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips);

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x="total_bill",y="tip",data=tips);

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x="total_bill",y="tip",data=tips, hue="sex");

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x="total_bill",y="tip",data=tips, hue="smoker");

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x="duration",y="waiting",data=geyser, hue="kind");

# %%
fig,ax = plt.subplots(1,2, figsize= (10,5))
sns.scatterplot(x="total_bill", y="tip",data=tips,ax=ax[0])
sns.scatterplot(x="total_bill", y="tip", hue="smoker",ax=ax[1], data=tips);

# %%
fig,ax = plt.subplots(1,2, figsize= (10,5),sharey=True)
sns.scatterplot(x="total_bill", y="tip",data=tips,ax=ax[0])
sns.scatterplot(x="total_bill", y="tip", hue="smoker",ax=ax[1], data=tips);

# %%
#condition = 'circumstances'
#morality = 'generosity'
#phrase = '{condition} {1} {0} {morality}'.format('in all', 'wins', condition, morality)
print('{condition} {0} {morality} {condition}'.format('in all', 'wins',condition = 'circumstances', morality = 'generosity'))
# Out:
# circumstances in all generosity circumstances

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x="total_bill", y="tip", s=200, alpha=0.5, data=tips);

# %%
sns.rugplot(x="weight",height=0.5,data=mpg);

# %%
sns.displot(x="weight", data=mpg);

# %%
sns.displot(x="weight",aspect=2, data=mpg);

# %%
sns.displot(x="weight",aspect=1, data=mpg);

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
sns.rugplot(x='weight',data=mpg, ax=ax[0],height=0.5)
sns.displot(x='weight', kde=False, data=mpg, ax=ax[1])  # figure level plot
# Out:
# C:\Users\e_kur\anaconda3\lib\site-packages\seaborn\distributions.py:2163: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.histplot(x="weight",data=mpg);

# %%
sns.histplot(x="weight",data=mpg, kde=True);

# %%
sns.histplot(x="weight",data=mpg, kde=True,bins=20);

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
sns.rugplot(x='weight',data=mpg, ax=ax[0],height=0.5)
sns.histplot(x='weight', kde=False, data=mpg, ax=ax[1]);

# %%
sns.set(style="darkgrid")
sns.histplot(x='weight', kde=False, data=mpg)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %%
sns.set(style="darkgrid")
sns.histplot(x='pulse', kde=False, data=exercise)
# Out:
# <AxesSubplot:xlabel='pulse', ylabel='Count'>

# %%
sns.histplot(data=planets,x="mass",kde=True);

# %%
sns.histplot(data=flights,x="passengers",kde=True);

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.displot(data=penguins,x='body_mass_g',bins=10,rug=True,kde=True);

# %%
sns.kdeplot(data=penguins,x='body_mass_g');

# %%
sns.kdeplot(data=penguins,x='body_mass_g',shade=True,color="red");

# %%
sns.kdeplot(data=tips,x='total_bill',y='tip');

# %%
fig,ax = plt.subplots(1,2, figsize=(10,5))
sns.scatterplot(x='total_bill', y='tip', data=tips, ax=ax[0])
sns.kdeplot(x='total_bill', y='tip', data=tips, ax=ax[1], shade=True, color='red');

# %%
sns.kdeplot(data=penguins,x='body_mass_g',y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="scatter");

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="kde");

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="reg");

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="hex");
